# %% [raw]
# -> count vectorizer counts occurance of each word
# ->

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../TextFiles/smsspamcollection.tsv',sep='\t')

# %%
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
len(df)
# Out:
# 5572

# %%
df['label'].unique()
# Out:
# <StringArray>
# ['ham', 'spam']
# Length: 2, dtype: str

# %%
df['label'].value_counts()
# Out:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
bins = 1.15**(np.arange(0,50))
sns.histplot(data=df,x='length',hue='label',bins=bins)
# Out:
# <Axes: xlabel='length', ylabel='Count'>

# %%
bins = 1.15**(np.arange(0,15))
sns.histplot(data=df,x='punct',hue='label',bins=bins,alpha=0.8)
# Out:
# <Axes: xlabel='punct', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split
X = df[['length','punct']]
Y = df['label']
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.20,random_state=101)

# %%
from sklearn.linear_model import LogisticRegression


model = LogisticRegression(solver='lbfgs')

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.88      0.97      0.92       980
#         spam       0.13      0.03      0.05       135
#
#     accuracy                           0.86      1115
#    macro avg       0.51      0.50      0.49      1115
# weighted avg       0.79      0.86      0.82      1115

# %%
from sklearn.naive_bayes import MultinomialNB


nb_model = MultinomialNB()

nb_model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
preds = nb_model.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.88      1.00      0.93       980
#         spam       0.20      0.01      0.01       135
#
#     accuracy                           0.88      1115
#    macro avg       0.54      0.50      0.47      1115
# weighted avg       0.80      0.88      0.82      1115

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
preds = model.predict(X_test)

# %%
print(classification_report(y_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.92      0.97      0.94       980
#         spam       0.59      0.35      0.44       135
#
#     accuracy                           0.89      1115
#    macro avg       0.75      0.66      0.69      1115
# weighted avg       0.88      0.89      0.88      1115
