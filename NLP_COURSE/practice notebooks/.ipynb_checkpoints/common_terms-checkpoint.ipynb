# %% [raw]
# -> Tokenization
#     $ This is the process of splitting the original text to component pieces or tokens.
#     $ Parts of sentence:
#         $ Prefix => Characters at the beginning
#         $ Suffix => Characters at the end
#         $ Infix => Characterts in between
#         $ Exception => Special case rule to split a string into several tokens or prevent a token  from being split when punctuation rules are applied.
#     $ We can use doc.ents to get the entities. and we can get the label using entity.label_. We can explain what that label means using spacy.explain(entity.label_)
#     $ We can also get nouns using doc.noun_chunks
#     $ We can use this library for visualization from spacy import displacy
#         $ This is for dependency visualization
#             displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
#         $ for entity visualization
#             displacy.render(doc,style='ent',jupyter=True,options={'distance':110})
# -> Stemming
#     $ This is the method of cataloging related words; it essentially chops of the words until the stem is reached.
#     $ Porter stemming
#         $ There are mappings to reduce the words from one to another
#             SSES -> SS
#             IES -> I
#         $ if the word is more sophisticated or lengthy then the word is mapped based on the checks.
#             ATIONAL -> ATE
#             EED -> EE => Feed will be Feed
#     $ Snowball Stemmer (English Stemmer or Porter2 Stemmer)
#         $ it has slight improvement over porter stemmer.
#     from nltk.stem.porter import PorterStemmer
#     p_stemmer = PorterStemmer()
#     p_stemmer.stem(word)
#
#     from nltk.stem.snowball import SnowballStemmer
#     s_stemmer = SnowballStemmer(language='english')
#     s_stemmer.stem(word)
# -> Lemmatization
#     $ Lemmatization looks at surrounding text to determine a given word's parts of speech, it does not categorize phrases.
#     $ lemmatization looks beyond word reduction, and considers a language's full vocabulary to apply a morphological analysis to words. The lemma of 'was' is 'be' and the lemma of 'mice' is 'mouse'. Further, the lemma of 'meeting' might be 'meet' or 'meeting' depending on its use in a sentence.
#     $ Lemmatization is the Natural Language Processing (NLP) technique of reducing inflected words to their base or dictionary form, known as the lemma
# -> Stop words
#     $ words like 'a' and 'the' appear so frequently that they do not require tagging as thorughly as nouns and verbs and these are called stop words.
#     $ We can check a stopword using
#         nlp.vocab['mystery'].is_stop
#     $ We can add or rmeove the stop words using below way
#         nlp.Defaults.stop_words.add('btw')
#         nlp.Defaults.stop_words.remove('not')
#     $ Remember based on the kind of analysis we are doing removing stopwords vs not removing them could change things.
# -> Vocabulary and matching
#     $ Rule Based Matching
#         $ spaCy offers a rule-matching tool called Matcher that allows you to build a library of token patterns, then match those patterns against a Doc object to return a list of found matches. You can match on any part of the token including text and annotations, and you can add multiple patterns to the same matcher.
#         $ We can initialize like below
#             from spacy.matcher import Matcher
#             matcher = Matcher(nlp.vocab)
#         $  match like below
#             pattern1 = [{'LOWER': 'solarpower'}]
#             pattern2 = [{'LOWER': 'solar'}, {'LOWER': 'power'}]
#             pattern3 = [{'LOWER': 'solar'}, {'IS_PUNCT': True}, {'LOWER': 'power'}]
#
#             matcher.add('SolarPower', None, pattern1, pattern2, pattern3)
#         $ get the matches for a certain doc
#             found_matches = matcher(doc)
#         $ We can pass the options and quantifiers
#             pattern2 = [{'LOWER': 'solar'}, {'IS_PUNCT': True, 'OP':'*'}, {'LOWER': 'power'}]
#     $ PhraseMatcher
#         $ method is to match on terminology lists. In this case we use PhraseMatcher to create a Doc object from a list of phrases, and pass that into matcher instead.
#         $ The PhraseMatcher is designed for speed and efficiency when working with large, fixed terminology lists, also known as gazetteers.
#         $ initializing
#             from spacy.matcher import PhraseMatcher
#             matcher = PhraseMatcher(nlp.vocab)
#         $ convert to docs
#             phrase_list = ['voodoo economics', 'supply-side economics', 'trickle-down economics', 'free-market economics']
#
#             # Next, convert each phrase to a Doc object:
#             phrase_patterns = [nlp(text) for text in phrase_list]
#         $ match the patterns
#             # Pass each Doc object into matcher (note the use of the asterisk!):
#             matcher.add('VoodooEconomics', None, *phrase_patterns)
#
#             # Build a list of matches:
#             matches = matcher(doc3)
# ->

# %%
import nltk
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
mystring = '"We\'re moving to L.A.!"'

# %%
doc = nlp(mystring)

# %%
for token in doc:
    print(token.text)
# Out:
# "
# We
# 're
# moving
# to
# L.A.
# !
# "

# %%
doc2 = nlp(u"We're here to help! Send snail-mail, email support@oursite.com or visit us at http://www.oursite.com!")

# %%
for t in doc2:
    print(t)
# Out:
# We
# 're
# here
# to
# help
# !
# Send
# snail
# -
# mail
# ,
# email
# support@oursite.com
# or
# visit
# us
# at
# http://www.oursite.com
# !

# %%
doc4 = nlp(u"Let's visit St. Louis in the U.S. next year.")

for t in doc4:
    print(t)
# Out:
# Let
# 's
# visit
# St.
# Louis
# in
# the
# U.S.
# next
# year
# .

# %%
len(doc4.vocab)
# Out:
# 786

# %%
doc5 = nlp(u"It is better to give than recieve")

# %%
doc5[0]
# Out:
# It

# %%
doc8 = nlp(u'Apple to build a Hong Kong factory for $6 million')

# %%
for token in doc8:
    print(token.text,end=' | ')
# Out:
# Apple | to | build | a | Hong | Kong | factory | for | $ | 6 | million |

# %%
for entity in doc8.ents:
    print(entity)
    print(entity.label_)
    print(spacy.explain(entity.label_))
    print('\n')
# Out:
# Apple
# ORG
# Companies, agencies, institutions, etc.
#
#
# Hong Kong
# GPE
# Countries, cities, states
#
#
# $6 million
# MONEY
# Monetary values, including unit

# %%
doc9 = nlp(u"Autonomous cars shift insurance liability toward manufacturers.")

for chunk in doc9.noun_chunks:
    print(chunk.text)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
for chunk in doc9.noun_chunks:
    print(chunk)
# Out:
# Autonomous cars
# insurance liability
# manufacturers

# %%
from spacy import displacy

# %%
doc = nlp(u'Apple is going to build a U.K. factory for $6 million.')

# %%
displacy.render(doc,style='dep',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9798703eca4241cea3c9fea7bbbfe75e-0" class="displacy" width="1370" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
# ...

# %%
displacy.render(doc,style='ent',jupyter=True,options={'distance':110})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is going to build a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.K.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  factory for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $6 million
# ...

# %%
doc = nlp("This is sentence")

# %%
# displacy.serve(doc,style='dep')

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
words = ['run','runner','running','ran','runs','easily','fairly']

# %%
for word in words:
    print(f'{word:{10}} => {p_stemmer.stem(word)}')
# Out:
# run        => run
# runner     => runner
# running    => run
# ran        => ran
# runs       => run
# easily     => easili
# fairly     => fairli

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
s_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
    print(f'{word:{10}} => {s_stemmer.stem(word)}')
# Out:
# run        => run
# runner     => runner
# running    => run
# ran        => ran
# runs       => run
# easily     => easili
# fairly     => fair

# %%
doc1 = nlp(u"I am a runner running in a race because I love to run since I ran today")

# %%
def show_lemmas(text):
    for token in text:
        print(f'{token.text:{12}} {token.pos_:{6}} {token.lemma:<{22}} {token.lemma_}')
show_lemmas(doc1)
# Out:
# I            PRON   4690420944186131903    I
# am           AUX    10382539506755952630   be
# a            DET    11901859001352538922   a
# runner       NOUN   12640964157389618806   runner
# running      VERB   12767647472892411841   run
# in           ADP    3002984154512732771    in
# a            DET    11901859001352538922   a
# race         NOUN   8048469955494714898    race
# because      SCONJ  16950148841647037698   because
# I            PRON   4690420944186131903    I
# love         VERB   3702023516439754181    love
# to           PART   3791531372978436496    to
# run          VERB   12767647472892411841   run
# since        SCONJ  10066841407251338481   since
# I            PRON   4690420944186131903    I
# ran          VERB   12767647472892411841   run
# today        NOUN   11042482332948150395   today

# %%
# print(nlp.Defaults.stop_words)

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop = False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)

# %%
# SolarPower
# Solar-Power
# Solar Power
pattern1 = [{'LOWER':'solarpower'}]
pattern2 = [{'LOWER':'solar'},{'IS_PUNCT':True},{'LOWER':'power'}]
pattern3 = [{'LOWER':'solar'},{'LOWER':'power'}]

# %%
matcher.add('SolarPower',[pattern1,pattern2,pattern3])

# %%
doc = nlp(u'The Solar Power industry continues to grow as demand \
for solarpower increases. Solar-power cars are gaining popularity.')

# %%
found_matches = matcher(doc)

# %%
found_matches
# Out:
# [(8656102463236116519, 1, 3),
#  (8656102463236116519, 10, 11),
#  (8656102463236116519, 13, 16)]

# %%
for match_id,start,end in found_matches:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(span)
# Out:
# Solar Power
# solarpower
# Solar-power

# %%
from spacy.matcher import PhraseMatcher

# %%
matcher = PhraseMatcher(nlp.vocab)

# %%
with open('../TextFiles/reaganomics.txt') as f:
    doc3 = nlp(f.read())

# %%
phrase_list = ['voodoo economics','trickle down economics','trickle down economics']

# %%
phrase_patterns = [nlp(text) for text in phrase_list]

# %%
matcher.add('Econmatcher',None,*phrase_patterns)

# %%
found_matches = matcher(doc3)

# %%
found_matches
# Out:
# [(14516527939337228634, 54, 56)]
