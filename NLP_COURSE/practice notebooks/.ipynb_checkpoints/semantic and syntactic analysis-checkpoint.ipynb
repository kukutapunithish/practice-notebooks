# %% [raw]
# -> word2vec can identify relation between words using vector operations
# -> consine similarity measures similarity between two words
# -> VADER (Valence aware dictionary for sentiment reasoning) is used for sentiment analysis

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

# %%
man_vec = nlp(u'man').vector
king_vec = nlp(u'king').vector

# %%
tokens = nlp(u'man women king queen')

# %%
for token1 in tokens:
    for token2 in tokens:
        print(f'{token1.text:{10}} {token2.text:{10}} {round(token1.similarity(token2),2):>{8}}')
# Out:
# man        man             1.0
# man        women          0.45
# man        king           0.41
# man        queen          0.27
# women      man            0.45
# women      women           1.0
# women      king           0.17
# women      queen          0.29
# king       man            0.41
# king       women          0.17
# king       king            1.0
# king       queen          0.73
# queen      man            0.27
# queen      women          0.29
# queen      king           0.73
# queen      queen           1.0

# %%
nlp.vocab.vectors.shape
# Out:
# (342918, 300)

# %%
from scipy import spatial

# %%
cosine_sim = lambda vec1,vec2: 1 - spatial.distance.cosine(vec1,vec2)

# %%
man = nlp(u'man').vector
king = nlp(u'king').vector
woman = nlp(u'woman').vector
queen = nlp(u'queen').vector

# %%
new_vec = king - man + woman

# %%
# new_vec

# %%
computed_sim = []

for word in nlp.vocab:
    if word.has_vector and word.is_lower and word.is_alpha:
        similarity = cosine_sim(new_vec,word.vector)
        computed_sim.append((word,similarity))

# %%
computed_sim = sorted(computed_sim,key=lambda item: -item[1])

# %%
for word,sim in computed_sim[:10]:
    print(word.text,sim)
# Out:
# king 0.8024259
# queen 0.78808445
# woman 0.51508135
# women 0.41247988
# she 0.39561844
# lion 0.38601506
# who 0.31594998
# when 0.28596795
# dare 0.28260577
# cat 0.27486885

# %%
import nltk

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nithishkumar\AppData\Roaming\nltk_data...
# True

# %%
nltk
