# %% [raw]
# -> computer vision is a general term for computer programs which process images.
# -> filters allow us to transform images
# -> A Convolutional Neural Network (CNN) is a neural network designed to process grid-like data (like images) by focusing on local patterns using filters.
# ->

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        # 1 input image channel (gray), 6 output channels, 3x3 square convolution
        self.conv1 = nn.Conv2d(1, 6, 3)
        self.pool = nn.MaxPool2d(2, 2)
        # Fully connected layers
        self.fc1 = nn.Linear(6 * 13 * 13, 128) 
        self.fc2 = nn.Linear(128, 10) # 10 classes (0-9 digits)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x))) # Conv -> ReLU -> Pool
        x = torch.flatten(x, 1)              # Flatten for FC layer
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Create the model
model = SimpleCNN()
print(model)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=1014, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
# Out:
# Linear(in_features=1014, out_features=128, bias=True)
