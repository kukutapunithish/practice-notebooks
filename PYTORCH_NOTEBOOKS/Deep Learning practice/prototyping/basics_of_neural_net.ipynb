# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
from micrograd.engine import Value

# %%
a = Value(4)
b = Value(5)

# %%
def f(x):
    return 3*x**2 - 4*x + 5

# %%
f(5)
# Out:
# 60
