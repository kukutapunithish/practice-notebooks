# %% [raw]
# -> A step-by-step representation of how a value is computed, used to efficiently calculate gradients.
# -> pytorch creates a computational graph during forward pass and while backward pass it calculates the gradients.
# -> We set the required_grad x = torch.tensor(2.0, requires_grad=True) to make the gradients during backward pass.
# ->

# %%
import torch

# %%
x = torch.tensor(2.0,requires_grad=True)

# %%
y = 2*x**4 + x**3 + 3*x**2 + 5*x + 1

# %%
print(y)
# Out:
# tensor(63., grad_fn=<AddBackward0>)

# %%
type(y)
# Out:
# torch.Tensor

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(93.)

# %%
x = torch.tensor([[1.,2.,3.],[3.,2.,1.]],requires_grad=True)

# %%
x
# Out:
# tensor([[1., 2., 3.],
#         [3., 2., 1.]], requires_grad=True)

# %%
y = 3*x + 2

# %%
y
# Out:
# tensor([[ 5.,  8., 11.],
#         [11.,  8.,  5.]], grad_fn=<AddBackward0>)

# %%
z = 2*y**2

# %%
z
# Out:
# tensor([[ 50., 128., 242.],
#         [242., 128.,  50.]], grad_fn=<MulBackward0>)

# %%
out = z.mean()

# %%
out
# Out:
# tensor(140., grad_fn=<MeanBackward0>)

# %%
out.backward()

# %%
print(x.grad)
# Out:
# tensor([[10., 16., 22.],
#         [22., 16., 10.]])

# %%
out
# Out:
# tensor(140., grad_fn=<MeanBackward0>)
