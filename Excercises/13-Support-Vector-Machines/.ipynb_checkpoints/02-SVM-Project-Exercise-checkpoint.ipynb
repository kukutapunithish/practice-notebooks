# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Copyright by Pierian Data Inc.</em></center>
# <center><em>For more information, visit us at <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Support Vector Machines
# ## Exercise
#
# ## [Fraud in Wine](https://en.wikipedia.org/wiki/Wine_fraud)
#
# Wine fraud relates to the commercial aspects of wine. The most prevalent type of fraud is one where wines are adulterated, usually with the addition of cheaper products (e.g. juices) and sometimes with harmful chemicals and sweeteners (compensating for color or flavor).
#
# Counterfeiting and the relabelling of inferior and cheaper wines to more expensive brands is another common type of wine fraud.
#
# <img src="wine.jpg">
#
# ## Project Goals
#
# A distribution company that was recently a victim of fraud has completed an audit of various samples of wine through the use of chemical analysis on samples. The distribution company specializes in exporting extremely high quality, expensive wines, but was defrauded by a supplier who was attempting to pass off cheap, low quality wine as higher grade wine. The distribution company has hired you to attempt to create a machine learning model that can help detect low quality (a.k.a "fraud") wine samples. They want to know if it is even possible to detect such a difference.
#
#
# Data Source: *P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis. Modeling wine preferences by data mining from physicochemical properties.
# In Decision Support Systems, Elsevier, 47(4):547-553, 2009.*
#
# ---
# ---
#
# **TASK: Your overall goal is to use the wine dataset shown below to develop a machine learning model that attempts to predict if a wine is "Legit" or "Fraud" based on various chemical features. Complete the tasks below to follow along with the project.**
#
# ---
# ---

# %% [markdown]
# ## Complete the Tasks in bold
#
# **TASK: Run the cells below to import the libraries and load the dataset.**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../DATA/wine_fraud.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# 2      9.8   Legit  red
# 3      9.8   Legit  red
# 4      9.4   Legit  red

# %% [markdown]
# **TASK: What are the unique variables in the target column we are trying to predict (quality)?**

# %%
df['quality'].value_counts()
# Out:
# quality
# Legit    6251
# Fraud     246
# Name: count, dtype: int64

# %%
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %% [markdown]
# **TASK: Create a countplot that displays the count per category of Legit vs Fraud. Is the label/target balanced or unbalanced?**

# %%
# CODE HERE
sns.countplot(x=df['quality'],hue=df['quality'])
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# **TASK: Let's find out if there is a difference between red and white wine when it comes to fraud. Create a countplot that has the wine *type* on the x axis with the hue separating columns by Fraud vs Legit.**

# %%
# CODE HERE
sns.countplot(x=df['type'],hue=df['quality'])
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# **TASK: What percentage of red wines are Fraud? What percentage of white wines are fraud?**

# %%
for type in ['white','red']:
    print(f'Percentage of fraud in {type} Wines:')
    print((df[(df['type'] == type) & (df['quality'] == 'Fraud')].shape[0]/df[(df['type'] == type)].shape[0])*100)
# Out:
# Percentage of fraud in white Wines:
# 3.7362188648427925
# Percentage of fraud in red Wines:
# 3.9399624765478425

# %%
# Out:
# Percentage of fraud in Red Wines:
# 3.9399624765478425

# %%
# Out:
# Percentage of fraud in White Wines:
# 3.7362188648427925

# %% [markdown]
# **TASK: Calculate the correlation between the various features and the "quality" column. To do this you may need to map the column to 0 and 1 instead of a string.**

# %%
df['quality'] = df['quality'].map({'Fraud': 1,'Legit':0})

# %%
df['type'] = df['type'].map({'red': 1,'white':0})

# %%
# CODE HERE
df.corr()['quality']
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# quality                 1.000000
# type                    0.004598
# Name: quality, dtype: float64

# %%
corr_mat = df.corr()['quality']

# %%
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# Fraud                   1.000000
# Name: Fraud, dtype: float64

# %% [markdown]
# **TASK: Create a bar plot of the correlation values to Fraudlent wine.**

# %%
# CODE HERE
sns.barplot(data=corr_mat.drop('quality').sort_values())
plt.xticks(rotation=90)
plt.show()

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# **TASK: Create a clustermap with seaborn to explore the relationships between variables.**

# %%
# CODE HERE
sns.clustermap(df.corr(),annot=True)

# %% [markdown]
# ----
# ## Machine Learning Model
#
# **TASK: Convert the categorical column "type" from a string or "red" or "white" to dummy variables:**

# %%
# CODE HERE
df['type'] = df['type'].map({1:'red' ,0:'white'})

# %%
dummy_type = pd.get_dummies(df['type']).drop('white',axis=1).astype(int)

# %%
df = pd.concat([df,dummy_type],axis=1)

# %% [markdown]
# **TASK: Separate out the data into X features and y target label ("quality" column)**

# %%
X = df.drop(columns = ['type','quality'])
Y = df['quality']

# %% [markdown]
# **TASK: Perform a Train|Test split on the data, with a 10% test size. Note: The solution uses a random state of 101**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size = 0.10,random_state=101)

# %% [markdown]
# **TASK: Scale the X train and X test data.**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **TASK: Create an instance of a Support Vector Machine classifier. Previously we have left this model "blank", (e.g. with no parameters). However, we already know that the classes are unbalanced, in an attempt to help alleviate this issue, we can automatically adjust weights inversely proportional to class frequencies in the input data with a argument call in the SVC() call. Check out the [documentation for SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html) online and look up what the argument\parameter is.**

# %%
# CODE HERE
from sklearn.svm import SVC

model = SVC(class_weight='balanced')

# %% [markdown]
# **TASK: Use a GridSearchCV to run a grid search for the best C and gamma parameters.**

# %%
# CODE HERE
from sklearn.model_selection import GridSearchCV

param_grid = {
    'gamma': ['scale', 'auto'],
    'C': np.linspace(0,1,2),
    'degree': [1],
    'kernel': ['rbf','linear','poly']
}

grid_model = GridSearchCV(param_grid=param_grid,cv=5,verbose=2,estimator=model,scoring='accuracy')

# %%
grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ...........C=0.0, degree=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=scale, kernel=rbf; total time=   0.0s
# [CV] END ........C=0.0, degree=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ........C=0.0, degree=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ........C=0.0, degree=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ........C=0.0, degree=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ........C=0.0, degree=1, gamma=scale, kernel=linear; total time=   0.0s
# [CV] END ..........C=0.0, degree=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ..........C=0.0, degree=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ..........C=0.0, degree=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ..........C=0.0, degree=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ..........C=0.0, degree=1, gamma=scale, kernel=poly; total time=   0.0s
# [CV] END ............C=0.0, degree=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=0.0, degree=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=0.0, degree=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=0.0, degree=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END ............C=0.0, degree=1, gamma=auto, kernel=rbf; total time=   0.0s
# [CV] END .........C=0.0, degree=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .........C=0.0, degree=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .........C=0.0, degree=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .........C=0.0, degree=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END .........C=0.0, degree=1, gamma=auto, kernel=linear; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV] END ...........C=0.0, degree=1, gamma=auto, kernel=poly; total time=   0.0s
# [CV] END ...........C=1.0, degree=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=scale, kernel=rbf; total time=   0.3s
# [CV] END ........C=1.0, degree=1, gamma=scale, kernel=linear; total time=   0.5s
# [CV] END ........C=1.0, degree=1, gamma=scale, kernel=linear; total time=   0.5s
# [CV] END ........C=1.0, degree=1, gamma=scale, kernel=linear; total time=   0.6s
# [CV] END ........C=1.0, degree=1, gamma=scale, kernel=linear; total time=   0.5s
# [CV] END ........C=1.0, degree=1, gamma=scale, kernel=linear; total time=   0.5s
# [CV] END ..........C=1.0, degree=1, gamma=scale, kernel=poly; total time=   0.3s
# [CV] END ..........C=1.0, degree=1, gamma=scale, kernel=poly; total time=   0.3s
# [CV] END ..........C=1.0, degree=1, gamma=scale, kernel=poly; total time=   0.3s
# [CV] END ..........C=1.0, degree=1, gamma=scale, kernel=poly; total time=   0.3s
# [CV] END ..........C=1.0, degree=1, gamma=scale, kernel=poly; total time=   0.3s
# [CV] END ............C=1.0, degree=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ............C=1.0, degree=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ............C=1.0, degree=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ............C=1.0, degree=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END ............C=1.0, degree=1, gamma=auto, kernel=rbf; total time=   0.3s
# [CV] END .........C=1.0, degree=1, gamma=auto, kernel=linear; total time=   0.5s
# [CV] END .........C=1.0, degree=1, gamma=auto, kernel=linear; total time=   0.5s
# [CV] END .........C=1.0, degree=1, gamma=auto, kernel=linear; total time=   0.5s
# [CV] END .........C=1.0, degree=1, gamma=auto, kernel=linear; total time=   0.6s
# [CV] END .........C=1.0, degree=1, gamma=auto, kernel=linear; total time=   0.5s
# [CV] END ...........C=1.0, degree=1, gamma=auto, kernel=poly; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=auto, kernel=poly; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=auto, kernel=poly; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=auto, kernel=poly; total time=   0.3s
# [CV] END ...........C=1.0, degree=1, gamma=auto, kernel=poly; total time=   0.3s
# C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 30 fits failed out of a total of 60.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\base.py", line 1329, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\base.py", line 492, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of SVC must be a float in the range (0.0, inf]. Got np.float64(0.0) instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#  0.85428732 0.78074415 0.78040169 0.8546295  0.78074415 0.7802306 ]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=SVC(class_weight='balanced'),
#              param_grid={'C': array([0., 1.]), 'degree': [1],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'linear', 'poly']},
#              scoring='accuracy', verbose=2)

# %%
grid_model.best_params_
# Out:
# {'C': np.float64(1.0), 'degree': 1, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
# Out:
# {'C': 1, 'gamma': 'auto'}

# %% [markdown]
# **TASK: Display the confusion matrix and classification report for your model.**

# %%
y_pred = grid_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       623
#            1       0.16      0.63      0.25        27
#
#     accuracy                           0.84       650
#    macro avg       0.57      0.74      0.58       650
# weighted avg       0.95      0.84      0.88       650

# %%
# Out:
# array([[ 17,  10],
#        [ 92, 531]], dtype=int64)

# %%
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.16      0.63      0.25        27
#        Legit       0.98      0.85      0.91       623
#
#     accuracy                           0.84       650
#    macro avg       0.57      0.74      0.58       650
# weighted avg       0.95      0.84      0.88       650

# %% [markdown]
# **TASK: Finally, think about how well this model performed, would you suggest using it? Realistically will this work?**

# %%
# ANSWER: View the solutions video for full discussion on this.
