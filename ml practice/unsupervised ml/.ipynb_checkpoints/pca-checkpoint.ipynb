# %% [raw]
# -> which features describe the most variance in the dataset
# -> aid human understanding of large feauresets especially through visualization
# -> principle component analysis outcomes
#     $ reduce number of dimensions in data.
#     $ show which features explain the most variance in the data.
# -> PCA steps
#     $ get original data
#     $ claculate covariance matrix
#     $ claculate eigen vectors
#     $ sort eigenvectores by eigen values
#     $ choose N largest eigen values
#     $ project original data onto eigenvectors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
