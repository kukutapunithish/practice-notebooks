# %% [raw]
# -> clustering is a unsupervised learning algorithm.
# -> it identifies similarities inorder to segment the data into seperate cluster.
# -> lack of groud truth to test the model. we have to have deep domain knowledge to uderstand the correctness.
# -> K-means
#     $ Must Satisfy
#         $ Each point must be in a cluster
#         $ a point can only be in one cluster
#     $ If we want clusters, we need a center for each cluster. That center is called a centroid. The centroid is simply the average position of points in that cluster.
#     $ K-Means uses an iterative guessing process.
#         $ Step 1: choose number of clusters
#         $ Step 2: initialize centroids => Randomly place two centroids.
#         $ Step 3: assign points to nearest centroid =>
#             For each data point:
#             calculate distance to centroid 1
#             calculate distance to centroid 2
#             assign to nearest centroid
#
#             Now clusters are formed.
#         $ Step 4: update centroids => Once clusters are formed, compute the new centroid. Centroid = mean of points in that cluster.
#         $ Step 5: repeat => assign points → recompute centroids → assign again
#         $ When centroids stop moving, the algorithm converges.
#     $ When centroids stop moving, the algorithm converges. So the algorithm tries to make clusters compact. => sum of square of (distance from point to its centroid).
#     $ Hyperparameters
#         $ n_clusters => number of clusters
#         $ init => what method to chose for choosing first randomly chosen values ('random','k-means++')
#         $ random_state => for reproducability
#         $ max_iter => number of iterations the model should repeat.
#     $ SSD (Inertia): Measures cluster tightness by summing the squared distances between points and their centroids; lower SSD means more compact clusters.
#     $ The Elbow: The optimal number of clusters (k) is found at the "bend" in the plot, where SSD stops dropping sharply and starts decreasing slowly.
# -> Image quantization
#     $ Image quantization is the process of reducing the number of colors in an image while trying to keep it visually similar to the original.
#     $ Images of greyscale are stored as a matrix of numbers between 0 to 1.
#     $ color images are stored as red,green,blue and each having 255 vlaues
#     $ We flatten the values so that the array is of size height * width for each of the red,blue,green
#     $ we find the cluster centers from the model, predictions
#     $ we can just use the cluster centers for each of the predictions say if predictions are like 1,1,0,0 then we just map 1 and 0's cluster center. what this essentially does is that it will get the average value of the pixcels around it.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../Excercises/DATA/bank-full.csv')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  str
#  2   marital         41188 non-null  str
#  3   education       41188 non-null  str
#  4   default         41188 non-null  str
#  5   housing         41188 non-null  str
#  6   loan            41188 non-null  str
#  7   contact         41188 non-null  str
#  8   month           41188 non-null  str
#  9   day_of_week     41188 non-null  str
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  str
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# duration        41188.0   258.285010  259.279249     0.000   102.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# ...

# %%
sns.histplot(data=df,x='age',bins=30,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
X = pd.get_dummies(df)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=2,random_state=101)

# %%
predictions = model.fit_predict(X_scaled)

# %%
predictions
# Out:
# array([1, 1, 1, ..., 0, 0, 0], shape=(41188,), dtype=int32)

# %%
np.unique(predictions)
# Out:
# array([0, 1], dtype=int32)

# %%
X['cluster'] = predictions

# %%
plt.figure(figsize=(12,6),dpi=150)
X.corr()['cluster'].iloc[:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=X,x='previous',y='previous',hue='cluster')
# Out:
# <Axes: xlabel='previous', ylabel='previous'>

# %%
ssd = []

for k in range(2,10):
    model = KMeans(n_clusters=k)
    model.fit(X_scaled)
    ssd.append(model.inertia_)

# %%
len(ssd),len(range(2,10))
# Out:
# [2469792.3788124025,
#  2382895.7994419197,
#  2329126.46370841,
#  2291214.576912272,
#  2159572.5723594995,
#  2123416.2732330044,
#  2093652.2034899043,
#  2073412.282488616]

# %%
plt.plot(range(2,10),ssd)

# %%
ssd_s = pd.Series(ssd)

# %%
ssd_s.diff()
# Out:
# 0              NaN
# 1    -86896.579370
# 2    -53769.335734
# 3    -37911.886796
# 4   -131642.004553
# 5    -36156.299126
# 6    -29764.069743
# 7    -20239.921001
# dtype: float64

# %%
import matplotlib.image as mpimg

# %%
image_as_array = mpimg.imread('../../Excercises/DATA/palm_trees.jpg')

# %%
# 934 X 1401

# %%
image_as_array[0].shape
# Out:
# (934, 3)

# %%
image_as_array.shape
# Out:
# (1401, 934, 3)

# %%
plt.imshow(image_as_array)

# %%
(h,w,c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w,c)

# %%
image_as_array2d.shape
# Out:
# (1308534, 3)

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=6)

# %%
preds = model.fit_predict(image_as_array2d)

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
preds
# Out:
# array([2, 2, 2, ..., 1, 1, 1], shape=(1308534,), dtype=int32)

# %%
quantized_image = np.reshape(rgb_codes[preds],(h,w,c))

# %%
# image_as_array2d
quantized_image
# Out:
# array([[[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 67,  62,  62],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        [[ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         ...,
#         [ 71, 109, 138],
#         [ 71, 109, 138],
#         [ 71, 109, 138]],
#
#        ...,
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
#         ...,
#         [  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4]],
#
#        [[  3,   3,   4],
#         [  3,   3,   4],
#         [  3,   3,   4],
# ...

# %%
plt.imshow(quantized_image)
