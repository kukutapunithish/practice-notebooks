# %% [raw]
# -> ML in general is the study of statistical computer algorithms that improve automatically through data.
# -> Structure of ML is like below
#     $ from features in a dataset obtain desired label.
#     $ ML algo are called estimators since they are estimating a desired label.
# -> types of ML
#     $ In supervised learning using historical and labeled data the model predicts a value.
#         $ Categorical value where classification is involved.
#         $ Continious task where regression is involved.
#     $ In un supervised learning deals with the unlabeled data which the model discovers possible patterns in the data.
# -> Machine learning process
#     $ collect & store data => clean & organize data => Exploratory Data Analysis => Machine Learning Models => Predict an outcome
# -> Features(X) and label(Y) and we will split the data for fair evaluation.
# -> Linear regresssion
#     $ We try to fit a linear equation to the data.
#     $ There will not be perfect fit so we try to calculate the difference of the each point to the linear line which is called the residual error.
#     $ Ordinary least squares tried to minimize the sum of square of difference between observed dependent variable and predicted variable.
#     $ LR builds relationship between features and target.
#     $ Each feature has beta coefficient associated.
#     $ y hat displays prediction since it is a estimation.
#     $ our goal is to predict the dependent variable with the help of independent variable.
#     $ In the simple linear regression or OLS has only one independent variable.
#     $ target feature is called explanatory variable since the target feature is trying to explain the independent variables.
#     $ Often times we might not account all the factors which might be imporant which causes omitted variable bias. these factor's are called unobserved features and deivation between the true and unobserved factor is called error.
#     $ A loss function tells the model how wrong it is so it knows how to improve.
#     $ loss function is calculating error for single datapoint and cost function is calculating the total loss for all the data points.
#     $ Gradient Descent is an algorithm that adjusts model parameters step-by-step to minimize the cost function. The slope is called the gradient (A matrix of derivatives of costfunction with respect to coefficients). gradient of the cost function and it tells the model where cost increases or decreases So the model moves in the opposite direction because we want to decrease the cost.
#     $ Learning Rate tells us How big should each step downhill be? we do this by taking each step proportional to the steep curve of the loss function and find the best possible coefficients.
#     $ Here derivates are used because they basically tells us How fast something changes when we change something else. (Derivative = how fast the cost changes when we change the parameter). in real world model there are many parameter and for each parameter there is a gradient and when we combine them in a matrix that becomes gradient. Every individual derivative becomes zero, meaning the surface is flat in every direction this is the minimum point we are trying to reach
#     $ In real world scenarios This surface has many valleys. Some valleys are shallow. One valley is the deepest.
#     Global minimum → the lowest valley overall
#     Local minimum → a valley that is lower than nearby points but not the lowest overall
#     Gradient Descent sometimes stops at local minima because it only follows the local slope, and the landscape may contain many valleys, not just one. many times a local minima is a good start and we can also use advanced optimizers like adam. These local minima points are called as saddle points.
# -> sklearn uses estimator api which is uniform framework for all the algorithm.
#     $ Train and Test split
#         from sklearn.model_selection import train_test_split
#         X_train,y_train,X_test,y_test = train_test_split(x,y,test_size=0.2)
#     $ for predictions
#         from sklearn.model_family import ModelAlgo
#         mymodel = ModelAlgo(param1,param2)
#         mymodel.fit(X_train,y_train)
#         predictions = mymodel.predict(X_test)
#     $  for evaluation
#         from sklearn import error_metric
#         performance = error_metric(y_test,predictions)
# -> Evaluation for performance
#     $ MAE takes the average of absolute residual or difference between actual and predicted. This does not penalize for large errors
#     $ MSE is the average sum of squared residual. This gets the answer in squared units.
#     $ RMSE is the square root of MSE which brings the error to same units.
#     $ We can check the error by average of the dataset to get the understanding of what is a good value.
#     $ We can take the percentage like RMSE/Avg of train set to get the understanding on an average x% off are all the values.
#
# -> Evaluation for assumptions
#     $ We can plot the residual plot distribution to check if it is normal distribution then it is correct.
#     $ We can plot residual vs true y-value scatterplot to check if the points are random which is correct. we can have a line at 0 to check this.
#
# -> Save the model
#     $ Below is the way we can save and load the model
#         from joblib import dump,load
#         dump(model,'model.joblib')
#         model = load(model.joblib)
#
# -> Polynomial regression
#     $ Polynomial regression allows linear regression to model curved relationships by adding powers of the input variable.
#     $ If curves fit data better, why not use a very high degree polynomial? The model may start fitting noise instead of patterns. passing exactly through every point. This is called overfitting. The model memorizes the training data but fails on new data.
#     $ Interaction terms are the multiplied combination of the available variable in the dataset.
#     $ Below code can be used for the transformation of features from normal variable to polynomial.
#         from sklearn.preprocessing import PolynomialFeatures
#         polynomial_convertor = PolynomialFeatures(degree=2,include_bias = False)
#         polynomial_convertor.fit(X)
#         poly_features = polynomial_convertor.transform(X)
#     $ Rest of the steps for splitting the data and predictions are same. note for splitting data pass the polinomial features (converted values).
#     $ We take the rmse for the train and test data and check how both are changing over the increase of degree to identify the optimal degree we just check where it is lease and just before it starts increasing again. this will help us to find the optimal degree.
#     $
#
#
# -> Bias variance tradeoff
#     $ The Bias–Variance Tradeoff explains why models must balance simplicity and flexibility:
# too simple → biased, too flexible → unstable.
#     $ Overfitting is when the model fits too much to noise and variance. this cases model to work well on training dataset but poorly on testing dataset.
#     $ In underfitting model does not capture the underlying trend of the data and does not fit the data well enough. this has high bias. this results in simple model.
#     $ model complexity is the capability of model to capture intricate details or trend of data. this is decided by model parameters, model architecture etc..
#     $ ideally a good model should have trend like as we increase the model complexity the error should decrease.
# -> Regularization
#     $ L1-regularization(Lasso): adds a penalty equal to the absolute value of the magnitude of coefficients
#         $ This limits the size of coefficients.
#         $ Can yeild sparse models where some coefficients can become zero.
#         $ RSS + absolute value of the magnitude of coefficients
#         $ absolute value of the magnitude of coefficients is multiplied by lamda and we can tune this lamda.
#     $ L2-regularization(Ridge): adds a penalty equal to the square absolute value of the magnitude of coefficients
#         $ it does not eliminate any coefficients.
#         $ the coefficients will be shrunk by a factor.
#         $ RSS + absolute value of the square absolute value of the magnitude of coefficients
#         $ Here as the coefficient increases in penality it will become squared so it will become much larger as we are trying to minimize this the slope won't increase as fast as it is happening.
#         $ Below is the code to train the Ridge model and similar code is used for the lasso
#         from sklearn.linear_model import Ridge
#         ridge_model = Ridge(alpha=10)
#         ridge_model.fit(X_train,y_train)
#         $ We can use the RidgeCV model to find the best alpha value for the best score.
#     $ ElasticNet: There is a aplpha parameter which decides the weightage of the L1 and L2 regularization.
#         $ Remove useless features but don't randomly discard correlated ones
#         $ alpha Controls how strong the regularization is overall.
#         $ l1_ratio Controls how much L1 vs L2.
#
# -> Feature Scaling
#     $ Feature scaling improves the convergence of steepest decent algorithms.
#     $ If features are on different scales certain weights update faster than the others since the feature values play a role in weight updates.
#     $ There are two ways to scale standardization and normalization
#         $ Standardization rescales the data to have a mean of 0 and standard deviation of 1. It is also called z-score normalization
#         $ Normalization rescales all data values to be between 0 and 1.
#     $ fit method calculates the necessary parameters like min,max,mean,std.
#     $ transform scales the data and returns the new scaled data.
#     $ We call fit on full data this will leak data since the info from traning will leak to testing dataset. so fit should be only be applied on training data.
#
# -> cross validation
#     $ splits the data to ksets.
#     $ for each iteration choose 1 set to test and rest to train and evaluate the model. we can average error rate.
#     $ There is a philosophy where after we train the dataset and we hyperparameter tune the model based on the testing metrics so can we truly say that there is no leak to the training data.
#     $ What we do to solve the above problem is to have a holdout test set where a portion of the dataset is taken which the model will never see and never adjusted to.
#     $ We can just present the final results from the holdout testset.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Excercises/08-Linear-Regression-Models/Advertising.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV'] + df['radio'] + df['newspaper'] + df['sales']

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_spend
# 0  230.1   37.8       69.2   22.1        359.2
# 1   44.5   39.3       45.1   10.4        139.3
# 2   17.2   45.9       69.3    9.3        141.7
# 3  151.5   41.3       58.5   18.5        269.8
# 4  180.8   10.8       58.4   12.9        262.9

# %%
sns.scatterplot(data=df,x='total_spend',y='sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
sns.regplot(data=df,x='total_spend',y='sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
x = df['total_spend']
y = df['sales']

# %%
slope,intercept = np.polyfit(x,y,deg=1)

# %%
potential_spend = np.linspace(0,500,100)

# %%
predicted_sales = intercept + potential_spend*slope

# %%
sns.scatterplot(data=df,x='total_spend',y='sales')
plt.plot(potential_spend,predicted_sales,color='red')

# %%
sns.pairplot(data=df[['TV', 'radio', 'newspaper', 'sales']])

# %%
mat = df[['TV', 'radio', 'newspaper', 'sales']].corr()
sns.heatmap(mat)
# Out:
# <Axes: >

# %%
x = df.drop(['total_spend','sales'],axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=47)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([-1.60499996e+01, -1.02403893e-01,  3.87187457e+01,  9.41991461e+00,
#         7.29997322e+00,  8.96750730e+00,  1.05482552e+01, -9.20544627e+01,
#         8.59930608e+00,  6.20212849e+01,  1.68697121e+01,  1.51071792e+01,
#         1.57617651e+01,  8.04055151e+00, -9.21080276e+04,  1.08717432e+01,
#         9.39208174e+00,  2.05907672e+01,  1.96423691e+01,  1.32152444e+01,
#         1.76154116e+01,  8.15063918e+01,  1.13294808e+01,  1.74458937e+01,
#         7.08637412e+00,  1.22057135e+01,  1.15714960e+01,  1.57930784e+01,
#         1.87460065e+01,  8.70955456e+00,  2.20654791e+01,  9.62072369e+00,
#         1.51967555e+01,  2.17204086e+01,  9.43841150e+00,  1.30426776e+01,
#         1.64836712e+01,  1.50077067e+01,  8.37727672e+00,  2.38266459e+01])

# %%
y_train.mean(),y_train.median()
# Out:
# (np.float64(14.295000000000002), np.float64(13.25))

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test,predictions)
print(mae)
# Out:
# 2312.3398531571

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,predictions)
print(mse)
# Out:
# 212155336.08108398

# %%
from sklearn.metrics import root_mean_squared_error

rmse = root_mean_squared_error(y_test,predictions)
print(rmse)
# Out:
# 14565.553064716903

# %%
# Percentage of error interms of mean will be 12% more than average so on an average it will be off by 12%
(1.7/14)*100
# Out:
# 12.142857142857142

# %%
residuals = y_test - predictions

# %%
sns.displot(residuals,bins=20,kde=True)

# %%
sns.scatterplot(x=y_test,y=residuals)
plt.axhline(y=0,color='red',ls='--')

# %%
# Polynomial regression

# %%
X = df.drop(columns = ['sales','total_spend'])
Y = df['sales']

# %%
X,Y
# Out:
# (            TV     radio  newspaper
#  0   230.100000 37.800000  69.200000
#  1    44.500000 39.300000  45.100000
#  2    17.200000 45.900000  69.300000
#  3   151.500000 41.300000  58.500000
#  4   180.800000 10.800000  58.400000
#  ..         ...       ...        ...
#  195  38.200000  3.700000  13.800000
#  196  94.200000  4.900000   8.100000
#  197 177.000000  9.300000   6.400000
#  198 283.600000 42.000000  66.200000
#  199 232.100000  8.600000   8.700000
#
#  [200 rows x 3 columns],
#  0     22.100000
#  1     10.400000
#  2      9.300000
#  3     18.500000
#  4     12.900000
#           ...
#  195    7.600000
#  196    9.700000
#  197   12.800000
#  198   25.500000
#  199   13.400000
#  Name: sales, Length: 200, dtype: float64)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_convertor = PolynomialFeatures(degree=2,include_bias = False)

# %%
polynomial_convertor.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_convertor.transform(X)

# %%
X
# Out:
#             TV     radio  newspaper
# 0   230.100000 37.800000  69.200000
# 1    44.500000 39.300000  45.100000
# 2    17.200000 45.900000  69.300000
# 3   151.500000 41.300000  58.500000
# 4   180.800000 10.800000  58.400000
# ..         ...       ...        ...
# 195  38.200000  3.700000  13.800000
# 196  94.200000  4.900000   8.100000
# 197 177.000000  9.300000   6.400000
# 198 283.600000 42.000000  66.200000
# 199 232.100000  8.600000   8.700000
#
# [200 rows x 3 columns]

# %%
X.iloc[0]
# Out:
# TV          230.100000
# radio        37.800000
# newspaper    69.200000
# Name: 0, dtype: float64

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(poly_features,Y,test_size=0.2,random_state=47)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test,predictions)
print('mae ',mae)
mse = mean_squared_error(y_test,predictions)
print('mse ',mse)
rmse = root_mean_squared_error(y_test,predictions)
print('rmse ',rmse)
# Out:
# mae  0.5010428495859747
# mse  0.4801785127157977
# rmse  0.6929491415073675

# %%
print((0.6929491415073723/14)*100)
# Out:
# 4.94963672505266

# %%
def metrics(actual,predictions):
    mae = mean_absolute_error(actual,predictions)
    print('mae ',mae)
    mse = mean_squared_error(actual,predictions)
    print('mse ',mse)
    rmse = root_mean_squared_error(actual,predictions)
    print('rmse ',rmse)
    return mae,mse,rmse

# %%
metrics_dict = {
    'degree': [],
    'mae_train': [],
    'mse_train': [],
    'rmse_train': [],
    'mae_test': [],
    'mse_test': [],
    'rmse_test': [],
}
for d in range(1,10):
    print(f'Degree - {d}')
    polynomial_convertor = PolynomialFeatures(degree=d,include_bias = False)
    polynomial_convertor.fit(X)
    poly_features = polynomial_convertor.transform(X)
    X_train,X_test,y_train,y_test = train_test_split(poly_features,Y,test_size=0.2,random_state=47)
    model = LinearRegression()
    model.fit(X_train,y_train)
    print('Train Metrics')
    mae,mse,rmse = metrics(y_train,model.predict(X_train))
    metrics_dict['degree'].append(d)
    metrics_dict['mae_train'].append(mae)
    metrics_dict['mse_train'].append(mse)
    metrics_dict['rmse_train'].append(rmse)
    
    predictions = model.predict(X_test)
    print('Test Metrics')
    mae,mse,rmse = metrics(y_test,predictions)
    metrics_dict['mae_test'].append(mae)
    metrics_dict['mse_test'].append(mse)
    metrics_dict['rmse_test'].append(rmse)
# Out:
# Degree - 1
# Train Metrics
# mae  1.2096802024371083
# mse  2.680672407511139
# rmse  1.6372759106244552
# Test Metrics
# mae  1.3836057179961654
# mse  3.2099110389833676
# rmse  1.7916224599461148
# Degree - 2
# Train Metrics
# mae  0.3926007631994981
# mse  0.3494990921076374
# rmse  0.5911844822960405
# Test Metrics
# mae  0.5010428495859747
# mse  0.4801785127157977
# rmse  0.6929491415073675
# Degree - 3
# Train Metrics
# mae  0.3068913655778247
# mse  0.21529653090913453
# rmse  0.4640005721000078
# Test Metrics
# mae  0.36009062496767397
# mse  0.26370344608080637
# rmse  0.5135206384175872
# Degree - 4
# Train Metrics
# mae  0.2696156283411394
# mse  0.13501349222898495
# rmse  0.36744182155680777
# Test Metrics
# mae  0.43920147520804054
# mse  0.40375991042701437
# rmse  0.6354210497198014
# Degree - 5
# Train Metrics
# mae  0.18120449988641663
# mse  0.05879317086113285
# rmse  0.24247303120374614
# Test Metrics
# mae  0.8106425719385065
# mse  7.853546649445745
# ...

# %%
df_metrics = pd.DataFrame(data=metrics_dict)

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

# %%
for col in df_metrics.columns:
    if df_metrics[col].dtype == float:
        df_metrics[col] = df_metrics[col].round(2)

# %%
cols = list(df_metrics.columns)
cols.sort()
df_metrics[cols]
# Out:
#    degree    mae_test  mae_train         mse_test  mse_train    rmse_test  \
# 0       1    1.380000   1.210000         3.210000   2.680000     1.790000
# 1       2    0.500000   0.390000         0.480000   0.350000     0.690000
# 2       3    0.360000   0.310000         0.260000   0.220000     0.510000
# 3       4    0.440000   0.270000         0.400000   0.140000     0.640000
# 4       5    0.810000   0.180000         7.850000   0.060000     2.800000
# 5       6    4.460000   0.170000       603.210000   0.050000    24.560000
# 6       7    2.260000   0.160000        79.890000   0.050000     8.940000
# 7       8   65.740000   0.170000    152985.660000   0.090000   391.130000
# 8       9 2312.340000   0.270000 212155336.080000   0.260000 14565.550000
#
#    rmse_train
# 0    1.640000
# 1    0.590000
# 2    0.460000
# 3    0.370000
# 4    0.240000
# 5    0.220000
# 6    0.230000
# 7    0.310000
# 8    0.510000

# %%
plt.plot(range(1,6),df_metrics['rmse_train'][:5],label='TRAIN_RMSE')
plt.plot(range(1,6),df_metrics['rmse_test'][:5],label='TEST_RMSE')
plt.xlabel('degree of polynomial')
plt.ylabel('RMSE')
plt.legend()

# %%
# Regularization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
scaled_X_train
# Out:
# array([[-0.09504644,  0.39284758, -0.79770594, ..., -0.18682689,
#         -0.16190745, -0.15450494],
#        [-1.55029167, -0.78240684, -0.28999476, ..., -0.18678792,
#         -0.16187617, -0.15448222],
#        [-1.5678671 , -1.3290368 ,  0.09548966, ..., -0.18679044,
#         -0.16178872, -0.1541643 ],
#        ...,
#        [-0.48287749, -0.6320836 ,  0.10019069, ..., -0.18633634,
#         -0.16148134, -0.15415447],
#        [-1.33704318,  1.02830491,  1.69383969, ...,  0.39792153,
#          0.22542861,  0.08947976],
#        [-1.20346994,  1.60226637, -0.99044815, ..., -0.18682961,
#         -0.16190796, -0.15450503]], shape=(160, 219))

# %%
scaled_X_test
# Out:
# array([[-1.66746118,  1.73209099,  2.13573646, ...,  2.2093339 ,
#          1.27050909,  0.65978585],
#        [-1.43429386, -1.50669154,  0.16130407, ..., -0.18682294,
#         -0.16184627, -0.1540017 ],
#        [ 0.92667164,  0.97364192,  1.86307675, ...,  0.62824237,
#          0.41967417,  0.24011856],
#        ...,
#        [ 1.04032605, -1.3290368 ,  0.34464423, ..., -0.18671259,
#         -0.16149565, -0.15312952],
#        [-1.72135915, -0.81657121, -1.12207698, ..., -0.18683014,
#         -0.161908  , -0.15450503],
#        [ 0.78138145,  0.67982831,  1.38357174, ...,  0.02283377,
#         -0.01798459, -0.06055514]], shape=(40, 219))

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=10)
ridge_model.fit(X_train,y_train)
# Out:
# C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\linear_model\_ridge.py:267: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn(
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(X_test)

# %%
metrics(y_test,test_predictions)
# Out:
# mae  2.6124386904667136
# mse  19.938739604201714
# rmse  4.465281581737227
# (2.6124386904667136, 19.938739604201714, 4.465281581737227)

# %%
from sklearn.linear_model import RidgeCV

# %%
ridge_cv_model = RidgeCV(alphas=(0.1,1,10))

# %%
ridge_cv_model.fit(X_train,y_train)
# Out:
# RidgeCV(alphas=(0.1, 1, 10))

# %%
ridge_cv_model.alpha_
# Out:
# 0.1

# %%
from sklearn.metrics import get_scorer_names

# %%
print(get_scorer_names())
# Out:
# ['accuracy', 'adjusted_mutual_info_score', 'adjusted_rand_score', 'average_precision', 'balanced_accuracy', 'completeness_score', 'd2_absolute_error_score', 'd2_brier_score', 'd2_log_loss_score', 'explained_variance', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'fowlkes_mallows_score', 'homogeneity_score', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted', 'matthews_corrcoef', 'mutual_info_score', 'neg_brier_score', 'neg_log_loss', 'neg_max_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_gamma_deviance', 'neg_mean_poisson_deviance', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_median_absolute_error', 'neg_negative_likelihood_ratio', 'neg_root_mean_squared_error', 'neg_root_mean_squared_log_error', 'normalized_mutual_info_score', 'positive_likelihood_ratio', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'r2', 'rand_score', 'recall', 'recall
# ...

# %%
predictions = ridge_cv_model.predict(X_test)

# %%
metrics(y_test,predictions)
# Out:
# mae  69.50895709417998
# mse  103231.85234425882
# rmse  321.2971402677883
# (69.50895709417998, 103231.85234425882, 321.2971402677883)
