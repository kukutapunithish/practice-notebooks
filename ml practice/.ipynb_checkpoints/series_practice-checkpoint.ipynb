# %% [raw]
# -> Pandas is a library used for dataanalysis.
# -> read and write data, intelligently grab the data based on indexing, logic, subsetting and more.
# -> It can handle missing data and restructure data.
# -> Series is a datastructure which stores as a array along with a named index (differentiator why this library is famous).
# -> We can use the pd.Series(data = mydata,index=myindex) to create a pandas series.
# -> For fetching a specific datapoint we can simply get it by the index of the value or name of the index if it is a named index.
# -> Dictonary can be directly passed into the pd.Series() to create a series with the key's as index and values as values of the series.
# -> We can add the series with simlply like series1 + series2 or we can do series1.add(series2) the later gives more options like to fill a value if it is missing there by avoiding the np.nan value if we try to add the two series were one value in series is not present.
# -> We can use the .dtype to get the datatype of the series also we can set the dtype while creating the series.
# ->

# %%
import numpy as np
import pandas as pd

# %%
# help(pd.Series)

# %%
myindex = ['usa','canada','mexico']

# %%
mydata = [1776,1867,1821]

# %%
myser = pd.Series(data = mydata,index=myindex)

# %%
myser
# Out:
# usa       1776
# canada    1867
# mexico    1821
# dtype: int64

# %%
myser[0]
# Out:
# C:\Users\nithishkumar\AppData\Local\Temp\ipykernel_28840\3030946548.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   myser[0]
# np.int64(1776)

# %%
myser['usa']
# Out:
# np.int64(1776)

# %%
ages = {'my':10,'yours':20}
pd.Series(ages)
# Out:
# my       10
# yours    20
# dtype: int64

# %%
# Imaginary Sales Data for 1st and 2nd Quarters for Global Company
q1 = {'Japan': 80, 'China': 450, 'India': 200, 'USA': 250}
q2 = {'Brazil': 100,'China': 500, 'India': 210,'USA': 260}

# %%
q1_sales = pd.Series(q1)
q2_sales = pd.Series(q2)

# %%
q1_sales,q2_sales
# Out:
# (Japan     80
#  China    450
#  India    200
#  USA      250
#  dtype: int64,
#  Brazil    100
#  China     500
#  India     210
#  USA       260
#  dtype: int64)

# %%
q1_sales*2
# Out:
# Japan    160
# China    900
# India    400
# USA      500
# dtype: int64

# %%
total = q1_sales + q2_sales

# %%
total
# Out:
# Brazil      NaN
# China     950.0
# India     410.0
# Japan       NaN
# USA       510.0
# dtype: float64

# %%
q1_sales.add(q2_sales,fill_value=0)
# Out:
# Brazil    100.0
# China     950.0
# India     410.0
# Japan      80.0
# USA       510.0
# dtype: float64

# %%
q1_sales.mul(q2_sales,fill_value=0)
# Out:
# Brazil         0.0
# China     225000.0
# India      42000.0
# Japan          0.0
# USA        65000.0
# dtype: float64

# %%
q1_sales.dtype
# Out:
# dtype('int64')
