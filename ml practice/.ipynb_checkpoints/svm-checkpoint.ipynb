# %% [raw]
# -> maximum margin calssifiers, support vector classifiers, support vector machines is the flow of understanding the SVM.
# -> Hyperplane => in a n-dimensional space a hyperplane is a flat affine subspace (linear algebra or a line which does not have fixed origin)  of hyperplane dimension n-1. if it is 1D it is called point, 2-D is line, 3D is a flat plane.
# -> Hyperplanes are used to seperate classes.
# -> maximum margin classifier
#     $ Use the seperator (hyperplane) which maximizes the margins between the classes. this is used in maximum margin classifier.
#     $ This classifier uses a hard margin for classification.
# -> support vector classifiers
#     $ Advantage of SVC is that soft margins allows us for misclassification inside the margin. This adds more bias to the model for generalization.
#     $ we need to go with the cross validation for the best threshold for the soft margin.
# -> Support vector machines
#     $ kernal transformation allows us to project the a dimension higher for better seperation with hyperplane.
#     $ kernal trick helps us by not recompute the datapoints again in the higher plane instead it uses the dot product of the transposition of the data points.
#     $ C is the value which says that how error should be allowed for the soft margins. in scikit learn it is inverse C.
#     $ vectors that come in cotact with the margin are called support vectors.
#     $ In the equation we can simply calculature the margin according to the support vectors instead of taking all datapoints.
#     $ We can replace the kernals for the dotproducts. Kernals essentially compute this transformation to higher dimension.
#     $ There are differnt kernals like linear kernal, polynnomial kernal, radial basis kernal.
# -> SVR
#     $ Uses margin to get the continious value for the given features.
#     $ support vectores decide the margin.
#     $ epsilon is used for length of the tube around the hyperplane which tells how much can be acceptable.
#     $ C says how much we need to penalize.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_svm_boundary(model,X,y):
    
    X = X.values
    y = y.values
    
    # Scatter Plot
    plt.scatter(X[:, 0], X[:, 1], c=y, s=30,cmap='seismic')

    
    # plot the decision function
    ax = plt.gca()
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()

    # create grid to evaluate model
    xx = np.linspace(xlim[0], xlim[1], 30)
    yy = np.linspace(ylim[0], ylim[1], 30)
    YY, XX = np.meshgrid(yy, xx)
    xy = np.vstack([XX.ravel(), YY.ravel()]).T
    Z = model.decision_function(xy).reshape(XX.shape)

    # plot decision boundary and margins
    ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5,
               linestyles=['--', '-', '--'])
    # plot support vectors
    ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
               linewidth=1, facecolors='none', edgecolors='k')
    plt.show()

# %%
df = pd.read_csv('../Excercises/DATA/mouse_viral_study.csv')

# %%
df.head()
# Out:
#    Med_1_mL  Med_2_mL  Virus Present
# 0  6.508231  8.582531              0
# 1  4.126116  3.073459              1
# 2  6.427870  6.369758              0
# 3  3.672953  4.905215              1
# 4  1.580321  2.440562              1

# %%
sns.scatterplot(data=df,x='Med_1_mL',y='Med_2_mL',hue='Virus Present')
# Out:
# <Axes: xlabel='Med_1_mL', ylabel='Med_2_mL'>

# %%
sns.scatterplot(data=df,x='Med_1_mL',y='Med_2_mL',hue='Virus Present')
x = np.linspace(0,10,100)
m=-1
b=11
y=m*x+b
plt.plot(x,y,'black')

# %%
from sklearn.svm import SVC

# %%
# help(SVC)

# %%
Y = df['Virus Present']
X = df.drop('Virus Present',axis=1)

# %%
model = SVC(kernel='linear',C=1000)

# %%
model.fit(X,Y)
# Out:
# SVC(C=1000, kernel='linear')

# %%
plot_svm_boundary(model,X,Y)
# Out:
# C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='sigmoid',C=1000)
model.fit(X,Y)
plot_svm_boundary(model,X,Y)
# Out:
# C:\Users\nithishkumar\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
